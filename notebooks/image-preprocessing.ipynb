# %%
from PIL import Image

# %%
img = Image.open('../../../Downloads/Makeup.jpeg')

# %%
img.size
# Out:
# (736, 920)

# %%
img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=736x920 at 0x7FBF860C1DC0>
